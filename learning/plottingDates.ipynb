# %% [markdown]
# # Question
# When does plotting dates have nice xticks
# versus spammed datetime objects everywhere

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
plt.style.use("ggplot")
plt.rcParams["font.size"] = 13
COLORS = list(sns.color_palette())

# %%
test_df = pd.DataFrame({
        'dates': pd.date_range(start='2015-05-01', end='2015-06-01', freq='H'),
        'values': np.linspace(0, 100, 745)
    })

test_df
# Out:
# /var/folders/_c/j62lsd3n7x9_vq272kdsl3fc0000gn/T/ipykernel_66884/1629776894.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   'dates': pd.date_range(start='2015-05-01', end='2015-06-01', freq='H'),
#                   dates      values
# 0   2015-05-01 00:00:00    0.000000
# 1   2015-05-01 01:00:00    0.134409
# 2   2015-05-01 02:00:00    0.268817
# 3   2015-05-01 03:00:00    0.403226
# 4   2015-05-01 04:00:00    0.537634
# ..                  ...         ...
# 740 2015-05-31 20:00:00   99.462366
# 741 2015-05-31 21:00:00   99.596774
# 742 2015-05-31 22:00:00   99.731183
# 743 2015-05-31 23:00:00   99.865591
# 744 2015-06-01 00:00:00  100.000000
#
# [745 rows x 2 columns]

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(data=test_df, x='dates', y='values')
# Out:
# <Axes: xlabel='dates', ylabel='values'>
